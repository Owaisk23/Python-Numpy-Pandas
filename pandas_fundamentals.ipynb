# %%
import numpy as np
import pandas as pd

# %% [markdown]
# DataFrame:

# %% [markdown]
# ### Creating DataFrame

# %%
# using lists
student_data = [
    [100,80,10],
    [90,70,7],
    [120,100,14],
    [80,50,2]
]

pd.DataFrame(student_data,columns=['iq','marks','package'])
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %%
# using dicts

student_dict = {
    'name':['ali','ahmed','saman','asma','qaiser','hina'],
    'iq':[100,90,120,80,0,0],
    'marks':[80,70,100,50,0,0],
    'package':[10,7,14,2,0,0]
}

students = pd.DataFrame(student_dict)
# students.set_index('name',inplace=True) #inplace=True mutable 
copyx =  students.set_index('name')
print(copyx)
# print(students)
# Out:
#          iq  marks  package
# name
# ali     100     80       10
# ahmed    90     70        7
# saman   120    100       14
# asma     80     50        2
# qaiser    0      0        0
# hina      0      0        0

# %%
# using read_csv
df = pd.read_csv('laptops.csv')
df
# Out:
#                                                  Laptop       Status   Brand  \
# 0     ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core...          New    Asus
# 1     Alurin Go Start Intel Celeron N4020/8GB/256GB ...          New  Alurin
# 2     ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core...          New    Asus
# 3     MSI Katana GF66 12UC-082XES Intel Core i7-1270...          New     MSI
# 4     HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB...          New      HP
# ...                                                 ...          ...     ...
# 2155  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2156  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2157  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2158  Razer Book 13 Intel Evo Core i7-1165G7/16GB/1T...  Refurbished   Razer
# 2159  Razer Book FHD+ Intel Evo Core i7-1165G7/16GB/...  Refurbished   Razer
#
#            Model                CPU  RAM  Storage Storage type       GPU  \
# 0     ExpertBook      Intel Core i5    8      512          SSD       NaN
# 1             Go      Intel Celeron    8      256          SSD       NaN
# 2     ExpertBook      Intel Core i3    8      256          SSD       NaN
# 3         Katana      Intel Core i7   16     1000          SSD  RTX 3050
# 4            15S      Intel Core i5   16      512          SSD       NaN
# ...          ...                ...  ...      ...          ...       ...
# 2155       Blade      Intel Core i7   16     1000          SSD  RTX 3060
# 2156       Blade      Intel Core i7   16     1000          SSD  RTX 3070
# 2157       Blade      Intel Core i7   32     1000          SSD  RTX 3080
# 2158        Book  Intel Evo Core i7   16     1000          SSD       NaN
# 2159        Book  Intel Evo Core i7   16      256          SSD       NaN
#
#       Screen Touch  Final Price
# 0       15.6    No      1009.00
# 1       15.6    No       299.00
# 2       15.6    No       789.00
# 3       15.6    No      1199.00
# 4       15.6    No       669.01
# ...      ...   ...          ...
# 2155    17.3    No      2699.99
# 2156    17.3    No      2899.99
# 2157    17.3    No      3399.99
# 2158    13.4   Yes      1899.99
# 2159    13.4   Yes      1699.99
#
# [2160 rows x 12 columns]

# %%
df.shape
# Out:
# (2160, 12)

# %% [markdown]
# ### DataFrame Attributes and Methods

# %%
# dtypes
df.dtypes
# Out:
# Laptop           object
# Status           object
# Brand            object
# Model            object
# CPU              object
# RAM               int64
# Storage           int64
# Storage type     object
# GPU              object
# Screen          float64
# Touch            object
# Final Price     float64
# dtype: object

# %%
# columns
df.columns
# Out:
# Index(['Laptop', 'Status', 'Brand', 'Model', 'CPU', 'RAM', 'Storage',
#        'Storage type', 'GPU', 'Screen', 'Touch', 'Final Price'],
#       dtype='object')

# %%
# values
df.values
# Out:
# array([['ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core i5-1235U/8GB/512GB SSD/15.6"',
#         'New', 'Asus', ..., 15.6, 'No', 1009.0],
#        ['Alurin Go Start Intel Celeron N4020/8GB/256GB SSD/15.6"', 'New',
#         'Alurin', ..., 15.6, 'No', 299.0],
#        ['ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core i3-1215U/8GB/256GB SSD/15.6"',
#         'New', 'Asus', ..., 15.6, 'No', 789.0],
#        ...,
#        ['Razer Blade 17 FHD 360Hz Intel Core i7-11800H/32GB/1TB SSD/RTX 3080/17.3"',
#         'Refurbished', 'Razer', ..., 17.3, 'No', 3399.99],
#        ['Razer Book 13 Intel Evo Core i7-1165G7/16GB/1TB SSD/13.4" Táctil',
#         'Refurbished', 'Razer', ..., 13.4, 'Yes', 1899.99],
#        ['Razer Book FHD+ Intel Evo Core i7-1165G7/16GB/256GB SSD/13.4" Táctil',
#         'Refurbished', 'Razer', ..., 13.4, 'Yes', 1699.99]], dtype=object)

# %%
# head and tail
df.head()
# Out:
#                                               Laptop Status   Brand  \
# 0  ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core...    New    Asus
# 1  Alurin Go Start Intel Celeron N4020/8GB/256GB ...    New  Alurin
# 2  ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core...    New    Asus
# 3  MSI Katana GF66 12UC-082XES Intel Core i7-1270...    New     MSI
# 4  HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB...    New      HP
#
#         Model            CPU  RAM  Storage Storage type       GPU  Screen  \
# 0  ExpertBook  Intel Core i5    8      512          SSD       NaN    15.6
# 1          Go  Intel Celeron    8      256          SSD       NaN    15.6
# 2  ExpertBook  Intel Core i3    8      256          SSD       NaN    15.6
# 3      Katana  Intel Core i7   16     1000          SSD  RTX 3050    15.6
# 4         15S  Intel Core i5   16      512          SSD       NaN    15.6
#
#   Touch  Final Price
# 0    No      1009.00
# 1    No       299.00
# 2    No       789.00
# 3    No      1199.00
# 4    No       669.01

# %%
df.tail(2)
# Out:
#                                                  Laptop       Status  Brand  \
# 2158  Razer Book 13 Intel Evo Core i7-1165G7/16GB/1T...  Refurbished  Razer
# 2159  Razer Book FHD+ Intel Evo Core i7-1165G7/16GB/...  Refurbished  Razer
#
#      Model                CPU  RAM  Storage Storage type  GPU  Screen Touch  \
# 2158  Book  Intel Evo Core i7   16     1000          SSD  NaN    13.4   Yes
# 2159  Book  Intel Evo Core i7   16      256          SSD  NaN    13.4   Yes
#
#       Final Price
# 2158      1899.99
# 2159      1699.99

# %%
# sample
df.sample(3)
# Out:
#                                                  Laptop       Status    Brand  \
# 1159  Samsung Galaxy Book3 Pro Intel Evo Core i7-136...          New  Samsung
# 947   HP 15S-FQ4104NS Intel Core i5-1155G7/8GB/256GB...          New       HP
# 1164  ASUS F415EA-EK1005W Intel Core i5-1135G7/8GB/5...  Refurbished     Asus
#
#             Model                CPU  RAM  Storage Storage type  GPU  Screen  \
# 1159  Galaxy Book  Intel Evo Core i7   16      512          SSD  NaN    16.0
# 947           15S      Intel Core i5    8      256          SSD  NaN    15.6
# 1164       F415EA      Intel Core i5    8      512          SSD  NaN    14.0
#
#      Touch  Final Price
# 1159    No      2099.00
# 947     No       494.81
# 1164    No       579.00

# %%
# info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2160 entries, 0 to 2159
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Laptop        2160 non-null   object
#  1   Status        2160 non-null   object
#  2   Brand         2160 non-null   object
#  3   Model         2160 non-null   object
#  4   CPU           2160 non-null   object
#  5   RAM           2160 non-null   int64
#  6   Storage       2160 non-null   int64
#  7   Storage type  2118 non-null   object
#  8   GPU           789 non-null    object
#  9   Screen        2156 non-null   float64
#  10  Touch         2160 non-null   object
#  11  Final Price   2160 non-null   float64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 202.6+ KB

# %%
# describe
df.describe()
# Out:
#                RAM      Storage       Screen  Final Price
# count  2160.000000  2160.000000  2156.000000  2160.000000
# mean     15.413889   596.294444    15.168112  1312.638509
# std       9.867815   361.220506     1.203329   911.475417
# min       4.000000     0.000000    10.100000   201.050000
# 25%       8.000000   256.000000    14.000000   661.082500
# 50%      16.000000   512.000000    15.600000  1031.945000
# 75%      16.000000  1000.000000    15.600000  1708.970000
# max     128.000000  4000.000000    18.000000  7150.470000

# %%
# isnull
df.isnull().sum()
# Out:
# Laptop             0
# Status             0
# Brand              0
# Model              0
# CPU                0
# RAM                0
# Storage            0
# Storage type      42
# GPU             1371
# Screen             4
# Touch              0
# Final Price        0
# dtype: int64

# %%
# duplicated
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# rename
df
# Out:
#                                                  Laptop       Status   Brand  \
# 0     ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core...          New    Asus
# 1     Alurin Go Start Intel Celeron N4020/8GB/256GB ...          New  Alurin
# 2     ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core...          New    Asus
# 3     MSI Katana GF66 12UC-082XES Intel Core i7-1270...          New     MSI
# 4     HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB...          New      HP
# ...                                                 ...          ...     ...
# 2155  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2156  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2157  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2158  Razer Book 13 Intel Evo Core i7-1165G7/16GB/1T...  Refurbished   Razer
# 2159  Razer Book FHD+ Intel Evo Core i7-1165G7/16GB/...  Refurbished   Razer
#
#            Model                CPU  RAM  Storage Storage type       GPU  \
# 0     ExpertBook      Intel Core i5    8      512          SSD       NaN
# 1             Go      Intel Celeron    8      256          SSD       NaN
# 2     ExpertBook      Intel Core i3    8      256          SSD       NaN
# 3         Katana      Intel Core i7   16     1000          SSD  RTX 3050
# 4            15S      Intel Core i5   16      512          SSD       NaN
# ...          ...                ...  ...      ...          ...       ...
# 2155       Blade      Intel Core i7   16     1000          SSD  RTX 3060
# 2156       Blade      Intel Core i7   16     1000          SSD  RTX 3070
# 2157       Blade      Intel Core i7   32     1000          SSD  RTX 3080
# 2158        Book  Intel Evo Core i7   16     1000          SSD       NaN
# 2159        Book  Intel Evo Core i7   16      256          SSD       NaN
#
#       Screen Touch  Final Price
# 0       15.6    No      1009.00
# 1       15.6    No       299.00
# 2       15.6    No       789.00
# 3       15.6    No      1199.00
# 4       15.6    No       669.01
# ...      ...   ...          ...
# 2155    17.3    No      2699.99
# 2156    17.3    No      2899.99
# 2157    17.3    No      3399.99
# 2158    13.4   Yes      1899.99
# 2159    13.4   Yes      1699.99
#
# [2160 rows x 12 columns]

# %%
# df['Brand'][0] = 'HP'
df.loc[0, 'Status'] = 'Refurbished'

# %%
df
# Out:
#                                                  Laptop       Status   Brand  \
# 0     ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core...  Refurbished    Asus
# 1     Alurin Go Start Intel Celeron N4020/8GB/256GB ...          New  Alurin
# 2     ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core...          New    Asus
# 3     MSI Katana GF66 12UC-082XES Intel Core i7-1270...          New     MSI
# 4     HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB...          New      HP
# ...                                                 ...          ...     ...
# 2155  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2156  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2157  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2158  Razer Book 13 Intel Evo Core i7-1165G7/16GB/1T...  Refurbished   Razer
# 2159  Razer Book FHD+ Intel Evo Core i7-1165G7/16GB/...  Refurbished   Razer
#
#            Model                CPU  RAM  Storage Storage type       GPU  \
# 0     ExpertBook      Intel Core i5    8      512          SSD       NaN
# 1             Go      Intel Celeron    8      256          SSD       NaN
# 2     ExpertBook      Intel Core i3    8      256          SSD       NaN
# 3         Katana      Intel Core i7   16     1000          SSD  RTX 3050
# 4            15S      Intel Core i5   16      512          SSD       NaN
# ...          ...                ...  ...      ...          ...       ...
# 2155       Blade      Intel Core i7   16     1000          SSD  RTX 3060
# 2156       Blade      Intel Core i7   16     1000          SSD  RTX 3070
# 2157       Blade      Intel Core i7   32     1000          SSD  RTX 3080
# 2158        Book  Intel Evo Core i7   16     1000          SSD       NaN
# 2159        Book  Intel Evo Core i7   16      256          SSD       NaN
#
#       Screen Touch  Final Price
# 0       15.6    No      1009.00
# 1       15.6    No       299.00
# 2       15.6    No       789.00
# 3       15.6    No      1199.00
# 4       15.6    No       669.01
# ...      ...   ...          ...
# 2155    17.3    No      2699.99
# 2156    17.3    No      2899.99
# 2157    17.3    No      3399.99
# 2158    13.4   Yes      1899.99
# 2159    13.4   Yes      1699.99
#
# [2160 rows x 12 columns]

# %%
df['Brand']
# Out:
# 0         Asus
# 1       Alurin
# 2         Asus
# 3          MSI
# 4           HP
#          ...
# 2155     Razer
# 2156     Razer
# 2157     Razer
# 2158     Razer
# 2159     Razer
# Name: Brand, Length: 2160, dtype: object

# %%
df.rename(columns={'Laptops':'Laptop'},inplace=True)
# df.rename(columns={'Brands':'Brand'})
df
# Out:
#                                                  Laptop       Status   Brand  \
# 0     ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core...  Refurbished    Asus
# 1     Alurin Go Start Intel Celeron N4020/8GB/256GB ...          New  Alurin
# 2     ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core...          New    Asus
# 3     MSI Katana GF66 12UC-082XES Intel Core i7-1270...          New     MSI
# 4     HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB...          New      HP
# ...                                                 ...          ...     ...
# 2155  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2156  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2157  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2158  Razer Book 13 Intel Evo Core i7-1165G7/16GB/1T...  Refurbished   Razer
# 2159  Razer Book FHD+ Intel Evo Core i7-1165G7/16GB/...  Refurbished   Razer
#
#            Model                CPU  RAM  Storage Storage type       GPU  \
# 0     ExpertBook      Intel Core i5    8      512          SSD       NaN
# 1             Go      Intel Celeron    8      256          SSD       NaN
# 2     ExpertBook      Intel Core i3    8      256          SSD       NaN
# 3         Katana      Intel Core i7   16     1000          SSD  RTX 3050
# 4            15S      Intel Core i5   16      512          SSD       NaN
# ...          ...                ...  ...      ...          ...       ...
# 2155       Blade      Intel Core i7   16     1000          SSD  RTX 3060
# 2156       Blade      Intel Core i7   16     1000          SSD  RTX 3070
# 2157       Blade      Intel Core i7   32     1000          SSD  RTX 3080
# 2158        Book  Intel Evo Core i7   16     1000          SSD       NaN
# 2159        Book  Intel Evo Core i7   16      256          SSD       NaN
#
#       Screen Touch  Final Price
# 0       15.6    No      1009.00
# 1       15.6    No       299.00
# 2       15.6    No       789.00
# 3       15.6    No      1199.00
# 4       15.6    No       669.01
# ...      ...   ...          ...
# 2155    17.3    No      2699.99
# 2156    17.3    No      2899.99
# 2157    17.3    No      3399.99
# 2158    13.4   Yes      1899.99
# 2159    13.4   Yes      1699.99
#
# [2160 rows x 12 columns]

# %% [markdown]
# ### Selecting cols from a DataFrame

# %%
# single cols
df['Brands']
# Out:
# 0          HP
# 1        Asus
# 2        Asus
# 3         MSI
# 4          HP
#         ...
# 2155    Razer
# 2156    Razer
# 2157    Razer
# 2158    Razer
# 2159    Razer
# Name: Brands, Length: 2160, dtype: object

# %%
df['Brands'][1]
# Out:
# 'Asus'

# %%
df['Brands'][1] = 'HP'
# Out:
# C:\Users\owaisahmed\AppData\Local\Temp\ipykernel_11956\2836745051.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Brands'][1] = 'HP'
# C:\Users\owaisahmed\AppData\Local\Temp\ipykernel_11956\2836745051.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Brands'][1] = 'HP'

# %%
# multiple cols
df[['Brand', 'Final Price']]
# Out:
#        Brand  Final Price
# 0       Asus      1009.00
# 1     Alurin       299.00
# 2       Asus       789.00
# 3        MSI      1199.00
# 4         HP       669.01
# ...      ...          ...
# 2155   Razer      2699.99
# 2156   Razer      2899.99
# 2157   Razer      3399.99
# 2158   Razer      1899.99
# 2159   Razer      1699.99
#
# [2160 rows x 2 columns]

# %%
hp_laptops  = df['Brand'] == 'HP'
hp_laptops
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 2155    False
# 2156    False
# 2157    False
# 2158    False
# 2159    False
# Name: Brand, Length: 2160, dtype: bool

# %% [markdown]
# ### Selecting rows from a DataFrame
#
# - **iloc** - searches using index positions

# %%
# single row
df.iloc[50]
# Out:
# Laptop          Apple MacBook Air Apple M1/8GB/256GB SSD/GPU H...
# Status                                                        New
# Brand                                                       Apple
# Model                                                 MacBook Air
# CPU                                                      Apple M1
# RAM                                                             8
# Storage                                                       256
# Storage type                                                  SSD
# GPU                                                           NaN
# Screen                                                       13.3
# Touch                                                          No
# Final Price                                                1219.0
# Name: 50, dtype: object

# %%
# multiple row
df[0:5]
# Out:
#                                              Laptops       Status Brands  \
# 0  ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core...  Refurbished     HP
# 1  Alurin Go Start Intel Celeron N4020/8GB/256GB ...  Refurbished     HP
# 2  ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core...  Refurbished   Asus
# 3  MSI Katana GF66 12UC-082XES Intel Core i7-1270...          New    MSI
# 4  HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB...          New     HP
#
#         Model            CPU  RAM  Storage Storage type       GPU  Screen  \
# 0  ExpertBook  Intel Core i5    8      512          SSD       NaN    15.6
# 1          Go  Intel Celeron    8      256          SSD       NaN    15.6
# 2  ExpertBook  Intel Core i3    8      256          SSD       NaN    15.6
# 3      Katana  Intel Core i7   16     1000          SSD  RTX 3050    15.6
# 4         15S  Intel Core i5   16      512          SSD       NaN    15.6
#
#   Touch  Final Price
# 0    No      1009.00
# 1    No       299.00
# 2    No       789.00
# 3    No      1199.00
# 4    No       669.01

# %%
df[2:15:2] # alternates records.
# Out:
#                                                Laptop       Status  Brands  \
# 2   ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core...  Refurbished    Asus
# 4   HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB...          New      HP
# 6   Lenovo Thinkpad E14 Gen 4 AMD Ryzen 5 5625U/8G...          New  Lenovo
# 8   Medion Akoya E15415 Intel Core i5-10210U/8GB/2...          New  Medion
# 10  Lenovo V15 IGL Intel Celeron N4020/8GB/256 GB ...          New  Lenovo
# 12  ASUS ROG Strix G15 G513RC-HN088 AMD Ryzen 7 68...          New    Asus
# 14  Lenovo IdeaPad 1 15ADA7 AMD Ryzen 3 3250U/8GB/...          New  Lenovo
#
#          Model            CPU  RAM  Storage Storage type       GPU  Screen  \
# 2   ExpertBook  Intel Core i3    8      256          SSD       NaN    15.6
# 4          15S  Intel Core i5   16      512          SSD       NaN    15.6
# 6     ThinkPad    AMD Ryzen 5    8      256          SSD       NaN    14.0
# 8        Akoya  Intel Core i5    8      256          SSD       NaN    15.6
# 10         V15  Intel Celeron    8      256          SSD       NaN    15.6
# 12         ROG    AMD Ryzen 7   16      512          SSD  RTX 3050    15.6
# 14     IdeaPad    AMD Ryzen 3    8      256          SSD       NaN    15.6
#
#    Touch  Final Price
# 2     No       789.00
# 4     No       669.01
# 6     No       909.00
# 8     No       519.00
# 10    No       349.00
# 12    No      1199.00
# 14    No       391.00

# %%
# fancy indexing
df.iloc[[0,3,6,8]]
# Out:
#                                               Laptop Status  Brands  \
# 0  ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core...    New    Asus
# 3  MSI Katana GF66 12UC-082XES Intel Core i7-1270...    New     MSI
# 6  Lenovo Thinkpad E14 Gen 4 AMD Ryzen 5 5625U/8G...    New  Lenovo
# 8  Medion Akoya E15415 Intel Core i5-10210U/8GB/2...    New  Medion
#
#         Model            CPU  RAM  Storage Storage type       GPU  Screen  \
# 0  ExpertBook  Intel Core i5    8      512          SSD       NaN    15.6
# 3      Katana  Intel Core i7   16     1000          SSD  RTX 3050    15.6
# 6    ThinkPad    AMD Ryzen 5    8      256          SSD       NaN    14.0
# 8       Akoya  Intel Core i5    8      256          SSD       NaN    15.6
#
#   Touch  Final Price
# 0    No       1009.0
# 3    No       1199.0
# 6    No        909.0
# 8    No        519.0
