# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('customer.csv')

# %%
df.sample(5)
# Out:
#     age  gender   review education purchased
# 30   73    Male  Average        UG        No
# 1    68  Female     Poor        UG        No
# 8    65  Female  Average        UG        No
# 19   97    Male     Poor        PG       Yes
# 20   57  Female  Average    School       Yes

# %% [markdown]
# ‘age’ — numerical data
#
# ‘gender’ — nominal categorical data
#
# ‘review’ — ordinal categorical data
#
# ‘education’ — ordinal categorical data
#
# ‘purchased’ — the target variable
#
# Let us separate ordinal data and learn how to encode them.

# %% [markdown]
# df.iloc[:, 2:] is a way to subset a DataFrame by selecting all rows and a subset of columns starting from the third column to the end of the DataFrame.

# %%
df = df.iloc[:,2:]

# %%
df.head()
# Out:
#     review education purchased
# 0  Average    School        No
# 1     Poor        UG        No
# 2     Good        PG        No
# 3     Good        PG        No
# 4  Average        UG        No

# %%
from sklearn.model_selection import train_test_split
X = df.drop('purchased', axis=1)
y = df['purchased']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
X_train.shape, X_test.shape
# Out:
# ((35, 2), (15, 2))

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
X_train
# Out:
#      review education
# 7      Poor    School
# 14     Poor        PG
# 45     Poor        PG
# 48     Good        UG
# 29  Average        UG
# 15     Poor        UG
# 30  Average        UG
# 32  Average        UG
# 16     Poor        UG
# 42     Good        PG
# 20  Average    School
# 43     Poor        PG
# 8   Average        UG
# 13  Average    School
# 25     Good    School
# 5   Average    School
# 17     Poor        UG
# 40     Good    School
# 49     Good        UG
# 1      Poor        UG
# 12     Poor    School
# 37  Average        PG
# 24  Average        PG
# 6      Good    School
# 23     Good    School
# 36     Good        UG
# 21  Average        PG
# 19     Poor        PG
# 9      Good        UG
# 39     Poor        PG
# 46     Poor        PG
# 3      Good        PG
# 0   Average    School
# 47     Good        PG
# 44  Average        UG

# %%
oe = OrdinalEncoder(categories=[['Poor','Average','Good'],['School','UG','PG']])
# oe is an object of ordinal encoder. OrdinalEncoder takes categories as an input which takes list.

# %%
oe.fit(X_train)
# Out:
# OrdinalEncoder(categories=[['Poor', 'Average', 'Good'], ['School', 'UG', 'PG']])

# %%
X_train[:5]
# Out:
#      review education
# 7      Poor    School
# 14     Poor        PG
# 45     Poor        PG
# 48     Good        UG
# 29  Average        UG

# %%
X_train = oe.transform(X_train)
X_test = oe.transform(X_test)

# %%
X_train[:5]
# Out:
# array([[0., 0.],
#        [0., 2.],
#        [0., 2.],
#        [2., 1.],
#        [1., 1.]])

# %%
le = LabelEncoder()

# %%
le.fit(y_train)
# Out:
# LabelEncoder()

# %%
le.classes_
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
y_train[:5]
# Out:
# 7     Yes
# 14    Yes
# 45    Yes
# 48    Yes
# 29    Yes
# Name: purchased, dtype: object

# %%
y_train = le.transform(y_train)
y_test = le.transform(y_test)

# %%
y_train[:5]
# Out:
# array([1, 1, 1, 1, 1])
