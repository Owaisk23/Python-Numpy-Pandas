# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('customer.csv')

# %%
df.head()
# Out:
#    age  gender   review education purchased
# 0   30  Female  Average    School        No
# 1   68  Female     Poor        UG        No
# 2   70  Female     Good        PG        No
# 3   72  Female     Good        PG        No
# 4   16  Female  Average        UG        No

# %%
df['gender'].value_counts()
# Out:
# gender
# Female    29
# Male      21
# Name: count, dtype: int64

# %% [markdown]
# ## 1. OneHotEncoding using Pandas

# %%
one_hot_encoded_data = pd.get_dummies(df, columns = ['gender'])
print(one_hot_encoded_data)
# Out:
#     age   review education purchased  gender_Female  gender_Male
# 0    30  Average    School        No           True        False
# 1    68     Poor        UG        No           True        False
# 2    70     Good        PG        No           True        False
# 3    72     Good        PG        No           True        False
# 4    16  Average        UG        No           True        False
# 5    31  Average    School       Yes           True        False
# 6    18     Good    School        No          False         True
# 7    60     Poor    School       Yes           True        False
# 8    65  Average        UG        No           True        False
# 9    74     Good        UG       Yes          False         True
# 10   98     Good        UG       Yes           True        False
# 11   74     Good        UG       Yes          False         True
# 12   51     Poor    School        No          False         True
# 13   57  Average    School        No           True        False
# 14   15     Poor        PG       Yes          False         True
# 15   75     Poor        UG        No          False         True
# 16   59     Poor        UG       Yes          False         True
# 17   22     Poor        UG       Yes           True        False
# 18   19     Good    School        No          False         True
# 19   97     Poor        PG       Yes          False         True
# 20   57  Average    School       Yes           True        False
# 21   32  Average        PG        No          False         True
# 22   18     Poor        PG       Yes           True        False
# 23   96     Good    School        No           True        False
# 24   16  Average        PG       Yes           True        False
# 25   57     Good    School        No           True        False
# 26   53     Poor        PG        No           True        False
# 27   69     Poor        PG        No           True        False
# 28   48     Poor    School        No          False         True
# 29   83  Average        UG       Yes           True        False
# 30   73  Average        UG        No          False         True
# 31   22     Poor    School       Yes           True        False
# 32   92  Average        UG       Yes          False         True
# 33   89     Good        PG       Yes           True        False
# 34   86  Average    School        No          False         True
# 35   74     Poor    School       Yes          False         True
# 36   34     Good        UG       Yes           True        False
# 37   94  Average        PG       Yes          False         True
# 38   45     Good    School        No           True        False
# 39   76     Poor        PG        No          False         True
# 40   39     Good    School        No          False         True
# 41   23     Good        PG       Yes          False         True
# 42   30     Good        PG       Yes           True        False
# 43   27     Poor        PG        No          False         True
# 44   77  Average        UG        No           True        False
# 45   61     Poor        PG       Yes          False         True
# 46   64     Poor        PG        No           True        False
# 47   38     Good        PG       Yes           True        False
# 48   39     Good        UG       Yes           True        False
# 49   25     Good        UG        No           True        False

# %%
# Convert only the one-hot encoded columns to integer type
for col in one_hot_encoded_data.columns:
    if col.startswith('gender_'):
        one_hot_encoded_data[col] = one_hot_encoded_data[col].astype(int)

print("\nFinal DataFrame with Integer Values for One-Hot Encoded Columns:\n", one_hot_encoded_data)
# Out:
# Final DataFrame with Integer Values for One-Hot Encoded Columns:
#      age   review education purchased  gender_Female  gender_Male
# 0    30  Average    School        No              1            0
# 1    68     Poor        UG        No              1            0
# 2    70     Good        PG        No              1            0
# 3    72     Good        PG        No              1            0
# 4    16  Average        UG        No              1            0
# 5    31  Average    School       Yes              1            0
# 6    18     Good    School        No              0            1
# 7    60     Poor    School       Yes              1            0
# 8    65  Average        UG        No              1            0
# 9    74     Good        UG       Yes              0            1
# 10   98     Good        UG       Yes              1            0
# 11   74     Good        UG       Yes              0            1
# 12   51     Poor    School        No              0            1
# 13   57  Average    School        No              1            0
# 14   15     Poor        PG       Yes              0            1
# 15   75     Poor        UG        No              0            1
# 16   59     Poor        UG       Yes              0            1
# 17   22     Poor        UG       Yes              1            0
# 18   19     Good    School        No              0            1
# 19   97     Poor        PG       Yes              0            1
# 20   57  Average    School       Yes              1            0
# 21   32  Average        PG        No              0            1
# 22   18     Poor        PG       Yes              1            0
# 23   96     Good    School        No              1            0
# 24   16  Average        PG       Yes              1            0
# 25   57     Good    School        No              1            0
# 26   53     Poor        PG        No              1            0
# 27   69     Poor        PG        No              1            0
# 28   48     Poor    School        No              0            1
# 29   83  Average        UG       Yes              1            0
# 30   73  Average        UG        No              0            1
# 31   22     Poor    School       Yes              1            0
# 32   92  Average        UG       Yes              0            1
# 33   89     Good        PG       Yes              1            0
# 34   86  Average    School        No              0            1
# 35   74     Poor    School       Yes              0            1
# 36   34     Good        UG       Yes              1            0
# 37   94  Average        PG       Yes              0            1
# 38   45     Good    School        No              1            0
# 39   76     Poor        PG        No              0            1
# 40   39     Good    School        No              0            1
# 41   23     Good        PG       Yes              0            1
# 42   30     Good        PG       Yes              1            0
# 43   27     Poor        PG        No              0            1
# 44   77  Average        UG        No              1            0
# 45   61     Poor        PG       Yes              0            1
# 46   64     Poor        PG        No              1            0
# 47   38     Good        PG       Yes              1            0
# 48   39     Good        UG       Yes              1            0
# 49   25     Good        UG        No              1            0

# %% [markdown]
# ## 2. K-1 OneHotEncoding

# %%
one_hot_encoded_data = pd.get_dummies(df,columns=['gender'],drop_first=True)

# %%
# Convert only the one-hot encoded columns to integer type
for col in one_hot_encoded_data.columns:
    if col.startswith('gender_'):
        one_hot_encoded_data[col] = one_hot_encoded_data[col].astype(int)

print("\nFinal DataFrame with Integer Values for One-Hot Encoded Columns:\n", one_hot_encoded_data)
# Out:
# Final DataFrame with Integer Values for One-Hot Encoded Columns:
#      age   review education purchased  gender_Male
# 0    30  Average    School        No            0
# 1    68     Poor        UG        No            0
# 2    70     Good        PG        No            0
# 3    72     Good        PG        No            0
# 4    16  Average        UG        No            0
# 5    31  Average    School       Yes            0
# 6    18     Good    School        No            1
# 7    60     Poor    School       Yes            0
# 8    65  Average        UG        No            0
# 9    74     Good        UG       Yes            1
# 10   98     Good        UG       Yes            0
# 11   74     Good        UG       Yes            1
# 12   51     Poor    School        No            1
# 13   57  Average    School        No            0
# 14   15     Poor        PG       Yes            1
# 15   75     Poor        UG        No            1
# 16   59     Poor        UG       Yes            1
# 17   22     Poor        UG       Yes            0
# 18   19     Good    School        No            1
# 19   97     Poor        PG       Yes            1
# 20   57  Average    School       Yes            0
# 21   32  Average        PG        No            1
# 22   18     Poor        PG       Yes            0
# 23   96     Good    School        No            0
# 24   16  Average        PG       Yes            0
# 25   57     Good    School        No            0
# 26   53     Poor        PG        No            0
# 27   69     Poor        PG        No            0
# 28   48     Poor    School        No            1
# 29   83  Average        UG       Yes            0
# 30   73  Average        UG        No            1
# 31   22     Poor    School       Yes            0
# 32   92  Average        UG       Yes            1
# 33   89     Good        PG       Yes            0
# 34   86  Average    School        No            1
# 35   74     Poor    School       Yes            1
# 36   34     Good        UG       Yes            0
# 37   94  Average        PG       Yes            1
# 38   45     Good    School        No            0
# 39   76     Poor        PG        No            1
# 40   39     Good    School        No            1
# 41   23     Good        PG       Yes            1
# 42   30     Good        PG       Yes            0
# 43   27     Poor        PG        No            1
# 44   77  Average        UG        No            0
# 45   61     Poor        PG       Yes            1
# 46   64     Poor        PG        No            0
# 47   38     Good        PG       Yes            0
# 48   39     Good        UG       Yes            0
# 49   25     Good        UG        No            0

# %% [markdown]
# ## 3. OneHotEncoding using Sklearn

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df.iloc[:,0:4],df.iloc[:,-1],test_size=0.2,random_state=2)

# %%
X_train.head()
# Out:
#     age  gender   review education
# 24   16  Female  Average        PG
# 48   39  Female     Good        UG
# 17   22  Female     Poor        UG
# 12   51    Male     Poor    School
# 27   69  Female     Poor        PG

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe = OneHotEncoder(drop='first',sparse=False,dtype=np.int32)

# %%
X_train_new = ohe.fit_transform(X_train[['gender']])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
X_test_new = ohe.transform(X_test[['gender']])

# %%
X_train_new.shape
# Out:
# (40, 1)

# %%
np.hstack((X_train[['gender']].values,X_train_new))
# Out:
# array([['Female', 0],
#        ['Female', 0],
#        ['Female', 0],
#        ['Male', 1],
#        ['Female', 0],
#        ['Female', 0],
#        ['Male', 1],
#        ['Female', 0],
#        ['Female', 0],
#        ['Male', 1],
#        ['Male', 1],
#        ['Female', 0],
#        ['Male', 1],
#        ['Female', 0],
#        ['Female', 0],
#        ['Male', 1],
#        ['Male', 1],
#        ['Male', 1],
#        ['Male', 1],
#        ['Female', 0],
#        ['Female', 0],
#        ['Male', 1],
#        ['Female', 0],
#        ['Female', 0],
#        ['Female', 0],
#        ['Female', 0],
#        ['Male', 1],
#        ['Female', 0],
#        ['Female', 0],
#        ['Male', 1],
#        ['Female', 0],
#        ['Female', 0],
#        ['Male', 1],
#        ['Male', 1],
#        ['Male', 1],
#        ['Female', 0],
#        ['Female', 0],
#        ['Male', 1],
#        ['Male', 1],
#        ['Male', 1]], dtype=object)
